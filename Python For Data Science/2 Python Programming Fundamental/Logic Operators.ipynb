# %%
## Logic operators

# %%
## or, agar dono main se koi ek sahi hai to true hoga, nahi to false hoga
## and, dono sahi hoga tab hi true hoga, nahi to false hoga

# %%
1=2
# Out:
#   Cell In[3], line 1
#     1=2
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
