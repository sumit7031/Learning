# %%
## operands(2,2,3 numbers) and operators(*,+,-,/)

# %%
43+63
# Out:
# 106

# %%
25/5
# Out:
# 5.0

# %%
25/6
# Out:
# 4.166666666666667

# %%
25//6
# Out:
# 4

# %%
## // make it rounded

# %%
c= 1

# %%
c
# Out:
# 1

# %%
c = 10
c
# Out:
# 10

# %%
# value got reassign
