# %%
float(2)
# Out:
# 2.0

# %%
int(1.1)
# Out:
# 1

# %%
int("1")
# Out:
# 1

# %%
int("A")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int("A")
#
# ValueError: invalid literal for int() with base 10: 'A'
